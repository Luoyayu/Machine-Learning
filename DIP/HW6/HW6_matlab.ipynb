% %%
lena_path = '/Volumes/MacMisc/Machine-Learning/DIP/lena.bmp';

% %%
rgb_img = imread(lena_path);
hsv_img = rgb2hsv(rgb_img);
cmy_img = imcomplement(rgb_img);
yum_img = 
imshow(rgb_img);

% %%
a = zeros(size(rgb_img, 1), size(rgb_img, 2));
fR = rgb_img(:, :, 1);
fG = rgb_img(:, :, 2);
fB = rgb_img(:, :, 3);

% %%
subplot(131)
imshow(cat(3, fR,a,a));title("R")
subplot(132)
imshow(cat(3, a, fG, a));title("G")
subplot(133)
imshow(cat(3, a,a,fB));title("B")
