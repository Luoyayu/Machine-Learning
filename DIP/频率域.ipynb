# %%
import dip_tools
from dip_tools import *

# %%
dip_tools.__version__
# Out:
# '0.1.0'

# %%
img_wb = np.zeros((257, 257))
center = [img_wb.shape[0]//2, img_wb.shape[1]//2]
img_wb[center[0]-10:center[0]+10, center[1]-60:center[1]+60] = 1
plot_gray_img(img_wb)

# %%
img_ms = got_magnitude_spectrum(img_wb, flag=0)
img_fs = got_magnitude_spectrum(img_wb, flag=1)
plot_two_gray_img(np.abs(img_ms), img_fs, '未中心化ft', '中心化ft')

# %%
plot_gray_img(got_ifft_img(img_ms), 'ifft')
